# %%
from michigrad.engine import Value
from michigrad.visualize import show_graph, show_graph_interactive
import numpy as np

# %%
from michigrad.nn import Neuron, Layer, MLP

# %%
# Definición de datos de entrada (xs) y las salidas esperadas (ys)

xs = [[Value(0), Value(0)], [Value(0), Value(1)], [Value(1), Value(0)], [Value(1), Value(1)]]
ys = [Value(0), Value(1), Value(1), Value(0)] 


# Definición del modelo
# El modelo XOR devuelve 0 si dos números binarios son iguales y 1 si son distintos
# entonces (0, 0), (1, 1) -> 0; (0, 1), (1, 0) --> 1 

xor_model = MLP(2, [2, 1], nonlin=False) 
    # dos entradas
    # una capa oculta con dos entradas
    # una salida
    # función de activación lineal
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 11
#       4 ys = [Value(0), Value(1), Value(1), Value(0)]
#       7 # Definición del modelo
#       8 # El modelo XOR devuelve 0 si dos números binarios son iguales y 1 si son distintos
#       9 # entonces (0, 0), (1, 1) -> 0; (0, 1), (1, 0) --> 1
# ---> 11 xor_model = MLP(2, [2, 1], nonlin=False)
#      12     # dos entradas
#      13     # una capa oculta con dos entradas
#      14     # una salida
#      15     # función de activación lineal
#
# TypeError: MLP.__init__() got an unexpected keyword argument 'nonlin'

# %%
xor_model.layers[2].neurons[0].nonlin
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 xor_model.layers[2].neurons[0].nonlin
#
# IndexError: list index out of range

# %%
# Entrenamiento del modelo
lr = 0.1

# iterar n veces
    # forward pass
    # loss (testear si a cada iteración disminuye)
    # zero grad
    # backward pass
    # update weights
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 for n in model.neurons:
#       2     print(n.w)
#       3     print(n.b)
#
# NameError: name 'model' is not defined

# %%
# Mostrar grafico de cómputo de la última neurona

show_graph(xor_model.layers[2])
